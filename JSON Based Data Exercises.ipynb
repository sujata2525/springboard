# %%
# Import pandas
import pandas as pd

# %%
# import for json data files

import json
from pandas.io.json import json_normalize

# %%
# define json string

data = [{'state': 'Florida', 
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
data
# Out:
# [{'counties': [{'name': 'Dade', 'population': 12345},
#    {'name': 'Broward', 'population': 40000},
#    {'name': 'Palm Beach', 'population': 60000}],
#   'info': {'governor': 'Rick Scott'},
#   'shortname': 'FL',
#   'state': 'Florida'},
#  {'counties': [{'name': 'Summit', 'population': 1234},
#    {'name': 'Cuyahoga', 'population': 1337}],
#   'info': {'governor': 'John Kasich'},
#   'shortname': 'OH',
#   'state': 'Ohio'}]

# %%
# use normalization to create tables from nested element
json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
# further populate tables created from nested element
json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %%
# load json as string
json.load((open('world_bank_projects_less.json')))

## Q: How to open dataset from any folder?
# Out:
# [{'_id': {'$oid': '52b213b38594d8a2be17c780'},
#   'approvalfy': 1999,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-12T00:00:00Z',
#   'borrower': 'FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA',
#   'closingdate': '2018-07-07T00:00:00Z',
#   'country_namecode': 'Federal Democratic Republic of Ethiopia!$!ET',
#   'countrycode': 'ET',
#   'countryname': 'Federal Democratic Republic of Ethiopia',
#   'countryshortname': 'Ethiopia',
#   'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 0,
#   'ibrdcommamt': 0,
#   'id': 'P129828',
#   'idacommamt': 130000000,
#   'impagency': 'MINISTRY OF EDUCATION',
#   'lendinginstr': 'Investment Project Financing',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 550000000,
#   'majorsector_percent': [{'Name': 'Education', 'Percent': 46},
#    {'Name': 'Education', 'Percent': 26},
# ...

# %%
# load as Pandas dataframe
sample_json_df = pd.read_json('C:\Personal\Springboard\Data Wrangling\data_wrangling_json\data\world_bank_projects.json')
sample_json_df
# Out:
#                                       _id  approvalfy board_approval_month  \
# 0    {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1    {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2    {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3    {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4    {'$oid': '52b213b38594d8a2be17c784'}        2014              October
# 5    {'$oid': '52b213b38594d8a2be17c785'}        2014              October
# 6    {'$oid': '52b213b38594d8a2be17c786'}        2014              October
# 7    {'$oid': '52b213b38594d8a2be17c787'}        2014              October
# 8    {'$oid': '52b213b38594d8a2be17c788'}        2014              October
# 9    {'$oid': '52b213b38594d8a2be17c789'}        2014              October
# 10   {'$oid': '52b213b38594d8a2be17c78a'}        2014              October
# ...

# %%
# find encoding value since data has some characters
import chardet

# %%
chardet.detect(df=sample_json_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6c775d5c059e> in <module>()
# ----> 1 chardet.detect(df=sample_json_df)
#
# TypeError: detect() got an unexpected keyword argument 'df'

# %%
  # Exercise 1 :Find the 10 countries with most projects

# %%
# Assign short-name to dataset as df
df= sample_json_df
df.head()
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2  {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3  {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4  {'$oid': '52b213b38594d8a2be17c784'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
# 2  2013-11-01T00:00:00Z   MINISTRY OF FINANCE AND ECONOMIC DEVEL
# 3  2013-10-31T00:00:00Z   MIN. OF PLANNING AND INT'L COOPERATION
# 4  2013-10-31T00:00:00Z                      MINISTRY OF FINANCE
#
#             closingdate                              country_namecode  \
# ...

# %%
# Check column names
df.columns
# Out:
# Index(['_id', 'approvalfy', 'board_approval_month', 'boardapprovaldate',
#        'borrower', 'closingdate', 'country_namecode', 'countrycode',
#        'countryname', 'countryshortname', 'docty', 'envassesmentcategorycode',
#        'grantamt', 'ibrdcommamt', 'id', 'idacommamt', 'impagency',
#        'lendinginstr', 'lendinginstrtype', 'lendprojectcost',
#        'majorsector_percent', 'mjsector_namecode', 'mjtheme',
#        'mjtheme_namecode', 'mjthemecode', 'prodline', 'prodlinetext',
#        'productlinetype', 'project_abstract', 'project_name', 'projectdocs',
#        'projectfinancialtype', 'projectstatusdisplay', 'regionname', 'sector',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector_namecode',
#        'sectorcode', 'source', 'status', 'supplementprojectflg', 'theme1',
#        'theme_namecode', 'themecode', 'totalamt', 'totalcommamt', 'url'],
#       dtype='object')

# %%
# Check more information on data
df.describe
# Out:
# <bound method NDFrame.describe of                                       _id  approvalfy board_approval_month  \
# 0    {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1    {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2    {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3    {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4    {'$oid': '52b213b38594d8a2be17c784'}        2014              October
# 5    {'$oid': '52b213b38594d8a2be17c785'}        2014              October
# 6    {'$oid': '52b213b38594d8a2be17c786'}        2014              October
# 7    {'$oid': '52b213b38594d8a2be17c787'}        2014              October
# 8    {'$oid': '52b213b38594d8a2be17c788'}        2014              October
# 9    {'$oid': '52b213b38594d8a2be17c789'}        2014              October
# 10   {'$oid': '52b213b38594d8a2be17c78a'}        2014              October
# ...

# %%
# Exercise 1 :Find the 10 countries with most projects

# %%
# Filter the original dataset to include only 2 columns for exercise 1 
country = df[['countryname', 'project_name']]
country.head()
# Out:
#                                countryname  \
# 0  Federal Democratic Republic of Ethiopia
# 1                      Republic of Tunisia
# 2                                   Tuvalu
# 3                        Republic of Yemen
# 4                       Kingdom of Lesotho
#
#                                         project_name
# 0  Ethiopia General Education Quality Improvement...
# 1          TN: DTF Social Protection Reforms Support
# 2  Tuvalu Aviation Investment Project - Additiona...
# 3   Gov't and Civil Society Organization Partnership
# 4  Second Private Sector Competitiveness and Econ...

# %%
country
# Out:
#                                   countryname  \
# 0     Federal Democratic Republic of Ethiopia
# 1                         Republic of Tunisia
# 2                                      Tuvalu
# 3                           Republic of Yemen
# 4                          Kingdom of Lesotho
# 5                           Republic of Kenya
# 6                           Republic of India
# 7                  People's Republic of China
# 8                           Republic of India
# 9                          Kingdom of Morocco
# 10                    Republic of South Sudan
# 11                          Republic of India
# 12                          Republic of Ghana
# 13         Democratic Republic of Timor-Leste
# 14                Hashemite Kingdom of Jordan
# 15                                      Samoa
# 16                                      Samoa
# 17                     Republic of Madagascar
# 18                        Kingdom of Cambodia
# ...

# %%
# Find projects for each county 
df.countryname.value_counts()
# Out:
# People's Republic of China                  19
# Republic of Indonesia                       19
# Socialist Republic of Vietnam               17
# Republic of India                           16
# Republic of Yemen                           13
# Kingdom of Morocco                          12
# People's Republic of Bangladesh             12
# Nepal                                       12
# Africa                                      11
# Republic of Mozambique                      11
# Federative Republic of Brazil                9
# Islamic Republic of Pakistan                 9
# Burkina Faso                                 9
# Republic of Armenia                          8
# Republic of Tajikistan                       8
# United Republic of Tanzania                  8
# Lao People's Democratic Republic             7
# Hashemite Kingdom of Jordan                  7
# Federal Republic of Nigeria                  7
# Kyrgyz Republic                              7
# ...

# %%
# Find top 10 countries with most projects
df.countryname.value_counts().head(10)
# Out:
# People's Republic of China         19
# Republic of Indonesia              19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Kingdom of Morocco                 12
# People's Republic of Bangladesh    12
# Nepal                              12
# Africa                             11
# Republic of Mozambique             11
# Name: countryname, dtype: int64

# %%
import matplotlib.pyplot as plt
df.countryname.value_counts().head(10).plot()
plt.show()

# %%
# Exercise 2: Find the top 10 major project themes (using column 'mjtheme_namecode')
# Filter the data for project themes
projects = df[['countryname', 'mjtheme_namecode']]

# %%
df['mjtheme_namecode'].head(1)
# Out:
# 0    [{'code': '8', 'name': 'Human development'}, {...
# Name: mjtheme_namecode, dtype: object

# %%
df2 = pd.DataFrame(columns=['code', 'name'])
df2
# Out:
# Empty DataFrame
# Columns: [code, name]
# Index: []

# %%
frames = []
for themes in df.mjtheme_namecode:
    frames.append(json_normalize(themes))
themes_df = pd.concat(frames, ignore_index=True)
top_themes = themes_df.groupby('code').size().sort_values(ascending=False).head(10)
totals = themes_df.code.value_counts().head(10)
themes_df.join(totals, on='code', how='inner', lsuffix='_left', rsuffix='_right').groupby(['code'])[['name','code_right']].max().sort_values(by="code_right", ascending=False)
# Out:
#                                               name  code_right
# code
# 11    Environment and natural resources management         250
# 10                               Rural development         216
# 8                                Human development         210
# 2                         Public sector governance         199
# 6            Social protection and risk management         168
# 4         Financial and private sector development         146
# 7                      Social dev/gender/inclusion         130
# 5                            Trade and integration          77
# 9                                Urban development          50
# 1                              Economic management          38

# %%
# Exercise 3 : In 2. above you will notice that some entries have only the code and the name is missing. 
# Create a dataframe with the missing names filled in.

# %%
themes_df
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# 16     11  Environment and natural resources management
# 17      8
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
np.count_nonzero(themes_df.isnull())
# Out:
# 0

# %%
df_no_missing = themes_df.dropna()

# %%
df_no_missing
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# 16     11  Environment and natural resources management
# 17      8
# ...

# %%
themes_df['name'].replace('', np.nan, inplace=True)

# %%
themes_df
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11                                           NaN
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6                                           NaN
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...
